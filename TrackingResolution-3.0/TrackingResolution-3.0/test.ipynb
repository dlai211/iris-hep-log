# %%
# import modules
import uproot, sys, time, random, argparse, copy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import awkward as ak
from tqdm import tqdm
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter
import matplotlib.ticker as ticker
from collections import Counter
from scipy.stats import norm
from math import *

# import trackingError function
from trackingerror import Detector, inputfromfile

# Set up plot defaults
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 14.0,10.0  # Roughly 11 cm wde by 8 cm high
mpl.rcParams['font.size'] = 20.0 # Use 14 point font
sns.set(style="whitegrid")

font_size = {
    "xlabel": 17,
    "ylabel": 17,
    "xticks": 15,
    "yticks": 15,
    "legend": 13,
    "title": 13,
}

plt.rcParams.update({
    "axes.labelsize": font_size["xlabel"],  # X and Y axis labels
    "xtick.labelsize": font_size["xticks"],  # X ticks
    "ytick.labelsize": font_size["yticks"],  # Y ticks
    "legend.fontsize": font_size["legend"]  # Legend
})

# %%
path = '/data/jlai/iris-hep/OutputPT/'
pT_values = [1, 3, 5, 10]
i = 1
file = uproot.open(path + f'output_pt_{pT_values[i]}' + '/tracksummary_ckf.root')
# file = uproot.open("/data/jlai/iris-hep/output_100000/tracksummary_ckf.root")

tree = file['tracksummary']

# < -- Fitting with no plot -- >
arrays = tree.arrays(["t_d0", "eLOC0_fit", "res_eLOC0_fit",
                      "t_z0", "eLOC1_fit", "res_eLOC1_fit",
                      "t_phi", "ePHI_fit", "res_ePHI_fit",
                      "t_theta", "eTHETA_fit", "res_eTHETA_fit",
                      "t_p", "eQOP_fit", "res_eQOP_fit",
                      "t_charge"], library='ak')

pT_truth = arrays['t_p'] * np.sin(arrays['t_theta'])
pT_reco = np.abs( 1 / arrays['eQOP_fit'] ) * np.sin(arrays['eTHETA_fit'])

labels = {
    'sigma(d)': ak.flatten(arrays['res_eLOC0_fit']) * 1e3, # converting from unit mm to unit um
    'sigma(z)': ak.flatten(arrays['res_eLOC1_fit']) * 1e3, # converting to unit um
    'sigma(phi)': ak.flatten(arrays['res_ePHI_fit']),
    'sigma(theta)': ak.flatten(arrays['res_eTHETA_fit']),
    'sigma(pt)/pt': ak.flatten((pT_reco - pT_truth) / pT_truth)
}

fit_results = {}
plt.figure(figsize=(30, 13))
for key, data in labels.items():
    data = ak.to_numpy(data)
    data = data[~np.isnan(data)]

    mu, sigma = norm.fit(data)
    fit_results[key] = sigma
    
    plt.subplot(231 + list(fit_results.keys()).index(key))
    counts, bins, _ = plt.hist(data, bins=100, histtype='step', linewidth=2, density=True, alpha=0.6, color='gray', label='Residuals')

    x = np.linspace(bins[0], bins[-1], 1000)
    plt.plot(x, norm.pdf(x, mu, sigma), 'r--', label=f'pT={pT_values[i]} Gaussian Fit\nμ = {mu:.2e}\nσ = {sigma:.2e}')

    plt.title(key)
    plt.xlabel(key)
    plt.ylabel("Frequency (normlized)")
    plt.legend()
    plt.grid(True)
plt.savefig(f'/data/jlai/iris-hep-log/TrackingResolution-3.0/TrackingResolution-3.0/plots/fitted_gaussian_pT{pT_values[i]}.png')

# < -- Tracking Error Calculator -- >
p, eta = pT_values[i], 0
B, m = 2, 0.106
mydetector = inputfromfile('ODD.txt', 1)
calc_result = mydetector.errorcalculation(p, B, eta, m)

# < -- plot comparsion -- >
var_labels = ['sigma(d)', 'sigma(z)', 'sigma(phi)', 'sigma(theta)', 'sigma(pt)/pt']
plt.figure(figsize=(20, 10))
for var_label in var_labels:
    idx = var_labels.index(var_label)
    plt.subplot(231 + idx)

    key = var_label
    y_calc = calc_result[var_label]
    y_acts = fit_results[key]

    plt.scatter(p, y_calc, marker='o', s=100, label=f"Calculator: {y_calc:.4g}")
    plt.scatter(p, y_acts, marker='x', s=100, label=f"ACTS (fit σ): {y_acts:.4g}")
    plt.xlabel(r"$p_T$ [GeV]")
    plt.ylabel(var_label)
    plt.title(f"{var_label} @ $p_T$ = {p} GeV, η = {eta}")
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# #	Width	Resolutionxy	Resolutionz	position
# 1  	0.00227	9999		9999		0.024
# 2  	0.01225	1.5e-05		1.5e-05		0.032
# 3  	0.01225	1.5e-05		1.5e-05		0.068
# 4  	0.01225	1.5e-05		1.5e-05		0.113
# 5  	0.01225	1.5e-05		1.5e-05		0.17
# 6  	0.01475	4.3e-05		0.0012		0.26
# 7  	0.01475	4.3e-05		0.0012		0.36
# 8  	0.01475	4.3e-05		0.0012		0.5
# 9  	0.01475	4.3e-05		0.0012		0.6
# 10 	0.225	0.072		9999		0.84
# 11 	0.225	0.072		9999		1.02
# Successfully read 11 layers

# %%
path = '/data/jlai/iris-hep/OutputPT/'
var_labels = ['sigma(d)', 'sigma(z)', 'sigma(phi)', 'sigma(theta)', 'sigma(pt)/pt']

y_acts = {label: [] for label in var_labels}
y_acts_err = {label: [] for label in var_labels}

pT_values = np.linspace(1, 10, 10)
for pT_value in pT_values:
    pT_value = int(pT_value)
    print(f'Saving ACTS track resol with pT = {pT_value} GeV')
    file = uproot.open(path + f'output_pt_{pT_value}' + '/tracksummary_ckf.root')
    tree = file['tracksummary']

    # < -- Fitting with no plot -- >
    arrays = tree.arrays(["t_d0", "eLOC0_fit", "res_eLOC0_fit",
                        "t_z0", "eLOC1_fit", "res_eLOC1_fit",
                        "t_phi", "ePHI_fit", "res_ePHI_fit",
                        "t_theta", "eTHETA_fit", "res_eTHETA_fit",
                        "t_p", "t_pT", "eQOP_fit", "res_eQOP_fit",
                        "t_charge"], library='ak')

    pT_truth = arrays['t_p'] * np.sin(arrays['t_theta'])
    pT_reco = np.abs( 1 / arrays['eQOP_fit'] ) * np.sin(arrays['t_theta'])

    labels = {
        'sigma(d)': ak.flatten(arrays['res_eLOC0_fit']) * 1e3, # converting from unit mm to unit um
        'sigma(z)': ak.flatten(arrays['res_eLOC1_fit']) * 1e3, # converting to unit um
        'sigma(phi)': ak.flatten(arrays['res_ePHI_fit']),
        'sigma(theta)': ak.flatten(arrays['res_eTHETA_fit']),
        'sigma(pt)/pt': ak.flatten((pT_reco - pT_truth) / pT_truth)
    }

    plt.figure(figsize=(30, 13))
    for key, data in labels.items():
        data = ak.to_numpy(data)
        data = data[~np.isnan(data)]

        mu, sigma = norm.fit(data)

        N = len(data)
        mu, sigma = norm.fit(data)
        y_acts[key].append(sigma)
        y_acts_err[key].append(sigma / np.sqrt(2 * N) if N > 0 else 0)
# Out:
# Saving ACTS track resol with pT = 1 GeV
# Saving ACTS track resol with pT = 2 GeV
# Saving ACTS track resol with pT = 3 GeV
# Saving ACTS track resol with pT = 4 GeV
# Saving ACTS track resol with pT = 5 GeV
# Saving ACTS track resol with pT = 6 GeV
# Saving ACTS track resol with pT = 7 GeV
# Saving ACTS track resol with pT = 8 GeV
# Saving ACTS track resol with pT = 9 GeV
# Saving ACTS track resol with pT = 10 GeV

# %%
# < -- Tracking Error Calculator -- >
def cal(inputfile='ODD.txt'):
    y_calc = {label: [] for label in var_labels}

    for pT_value in pT_values:
        pT_value = int(pT_value)
        p, eta = pT_value, 0
        B, m = 2, 0.106
        mydetector = inputfromfile(inputfile, 0)
        calc_result = mydetector.errorcalculation(p, B, eta, m)

        for var_label in var_labels:
            y_calc[var_label].append(calc_result[var_label])
    return y_calc


y_calc = cal('ODD.txt')
y_calc2 = cal('myODD.txt')

# < -- plot the var vs. pT -- >
plt.figure(figsize=(20, 10))
for var_label in var_labels:
    idx = var_labels.index(var_label)
    plt.subplot(231 + idx)

    plt.plot(pT_values, y_calc[var_label], 'o--', label=f"Calculator")
    plt.plot(pT_values, y_calc2[var_label], 'o--', label=f"Calculator2")
    # plt.plot(pT_values, y_acts[var_label], 'x--', label=f"ACTS (fit σ)")
    plt.errorbar(pT_values, y_acts[var_label], yerr=y_acts_err[var_label], fmt='x--', capsize=2, label="ACTS Fit σ ± Δσ")
    plt.xlabel(r"$p_T$ [GeV]")
    plt.ylabel(var_label)
    plt.title(f"{var_label} @ $p_T$ = {p} GeV, η = {eta}")
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers
# Successfully read 11 layers

# %%
si = 0.125 / 93.6
kap = 0.25 / 286
al = 0.15 / 89
carbon_foam = 2 / 1890
ti = 0.1 / 36.1
cu = 0.25 / 14.3
carbon_fiber = 2 / 2600
# Out:
# 0.0006002500000000001

# %%
f = uproot.open("/data/jlai/iris-hep/acts/thirdparty/OpenDataDetector/data/odd-material-maps.root")
f.keys()
# Out:
# ['SurfaceMaterial_vol2_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol2_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay4_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay6_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay8_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay10_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay12_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay14_app0_sen0/rho;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/n;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/v;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/o;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/min;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/max;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/t;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/x0;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/l0;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/A;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/Z;1',
#  'SurfaceMaterial_vol16_bou0_lay16_app0_sen0/rho;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/n;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/v;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/o;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/min;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/max;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/t;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/x0;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/l0;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/A;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/Z;1',
#  'SurfaceMaterial_vol17_bou0_lay2_app2_sen0/rho;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/n;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/v;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/o;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/min;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/max;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/t;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/x0;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/l0;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/A;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/Z;1',
#  'SurfaceMaterial_vol17_bou0_lay4_app2_sen0/rho;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/n;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/v;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/o;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/min;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/max;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/t;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/x0;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/l0;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/A;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/Z;1',
#  'SurfaceMaterial_vol17_bou0_lay6_app2_sen0/rho;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/n;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/v;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/o;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/min;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/max;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/t;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/x0;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/l0;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/A;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/Z;1',
#  'SurfaceMaterial_vol17_bou0_lay8_app2_sen0/rho;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol17_bou1_lay0_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay4_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay6_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay8_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay10_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay12_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay14_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou0_lay16_app0_sen0/rho;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol18_bou1_lay0_app0_sen0/rho;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol20_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol23_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/n;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/v;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/o;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/min;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/max;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/t;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/x0;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/l0;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/A;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/Z;1',
#  'SurfaceMaterial_vol23_bou0_lay4_app0_sen0/rho;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/n;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/v;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/o;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/min;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/max;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/t;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/x0;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/l0;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/A;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/Z;1',
#  'SurfaceMaterial_vol23_bou0_lay6_app0_sen0/rho;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/n;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/v;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/o;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/min;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/max;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/t;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/x0;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/l0;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/A;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/Z;1',
#  'SurfaceMaterial_vol23_bou0_lay8_app0_sen0/rho;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/n;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/v;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/o;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/min;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/max;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/t;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/x0;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/l0;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/A;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/Z;1',
#  'SurfaceMaterial_vol23_bou0_lay10_app0_sen0/rho;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/n;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/v;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/o;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/min;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/max;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/t;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/x0;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/l0;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/A;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/Z;1',
#  'SurfaceMaterial_vol23_bou0_lay12_app0_sen0/rho;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/n;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/v;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/o;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/min;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/max;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/t;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/x0;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/l0;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/A;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/Z;1',
#  'SurfaceMaterial_vol24_bou0_lay2_app1_sen0/rho;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/n;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/v;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/o;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/min;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/max;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/t;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/x0;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/l0;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/A;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/Z;1',
#  'SurfaceMaterial_vol24_bou0_lay4_app1_sen0/rho;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/n;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/v;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/o;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/min;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/max;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/t;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/x0;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/l0;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/A;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/Z;1',
#  'SurfaceMaterial_vol24_bou0_lay6_app1_sen0/rho;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/n;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/v;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/o;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/min;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/max;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/t;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/x0;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/l0;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/A;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/Z;1',
#  'SurfaceMaterial_vol24_bou0_lay8_app1_sen0/rho;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol24_bou1_lay0_app0_sen0/rho;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol25_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/n;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/v;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/o;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/min;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/max;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/t;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/x0;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/l0;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/A;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/Z;1',
#  'SurfaceMaterial_vol25_bou0_lay4_app0_sen0/rho;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/n;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/v;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/o;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/min;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/max;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/t;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/x0;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/l0;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/A;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/Z;1',
#  'SurfaceMaterial_vol25_bou0_lay6_app0_sen0/rho;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/n;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/v;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/o;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/min;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/max;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/t;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/x0;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/l0;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/A;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/Z;1',
#  'SurfaceMaterial_vol25_bou0_lay8_app0_sen0/rho;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/n;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/v;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/o;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/min;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/max;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/t;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/x0;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/l0;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/A;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/Z;1',
#  'SurfaceMaterial_vol25_bou0_lay10_app0_sen0/rho;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/n;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/v;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/o;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/min;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/max;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/t;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/x0;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/l0;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/A;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/Z;1',
#  'SurfaceMaterial_vol25_bou0_lay12_app0_sen0/rho;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol25_bou1_lay0_app0_sen0/rho;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol28_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/n;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/v;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/o;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/min;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/max;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/t;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/x0;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/l0;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/A;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/Z;1',
#  'SurfaceMaterial_vol28_bou0_lay4_app0_sen0/rho;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/n;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/v;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/o;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/min;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/max;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/t;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/x0;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/l0;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/A;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/Z;1',
#  'SurfaceMaterial_vol28_bou0_lay6_app0_sen0/rho;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/n;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/v;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/o;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/min;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/max;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/t;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/x0;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/l0;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/A;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/Z;1',
#  'SurfaceMaterial_vol28_bou0_lay8_app0_sen0/rho;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/n;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/v;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/o;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/min;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/max;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/t;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/x0;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/l0;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/A;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/Z;1',
#  'SurfaceMaterial_vol28_bou0_lay10_app0_sen0/rho;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/n;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/v;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/o;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/min;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/max;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/t;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/x0;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/l0;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/A;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/Z;1',
#  'SurfaceMaterial_vol28_bou0_lay12_app0_sen0/rho;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/n;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/v;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/o;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/min;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/max;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/t;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/x0;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/l0;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/A;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/Z;1',
#  'SurfaceMaterial_vol29_bou0_lay2_app1_sen0/rho;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/n;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/v;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/o;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/min;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/max;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/t;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/x0;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/l0;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/A;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/Z;1',
#  'SurfaceMaterial_vol29_bou0_lay4_app1_sen0/rho;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol29_bou1_lay0_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou0_lay4_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou0_lay6_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou0_lay8_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou0_lay10_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou0_lay12_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou1_lay0_app0_sen0/rho;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol30_bou4_lay0_app0_sen0/rho;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/n;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/v;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/o;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/min;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/max;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/t;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/x0;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/l0;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/A;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/Z;1',
#  'SurfaceMaterial_vol31_bou0_lay2_app0_sen0/rho;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/n;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/v;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/o;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/min;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/max;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/t;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/x0;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/l0;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/A;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/Z;1',
#  'SurfaceMaterial_vol31_bou4_lay0_app0_sen0/rho;1']

# %%
SurfaceMaterial_vol24_bou0_lay2_app1_sen0
SurfaceMaterial_vol24_bou0_lay4_app1_sen0
SurfaceMaterial_vol24_bou0_lay6_app1_sen0
SurfaceMaterial_vol24_bou0_lay8_app1_sen0
SurfaceMaterial_vol24_bou1_lay0_app0_sen0

SurfaceMaterial_vol29_bou0_lay2_app1_sen0
SurfaceMaterial_vol29_bou0_lay4_app1_sen0
SurfaceMaterial_vol29_bou1_lay0_app0_sen0

# %%
'SurfaceMaterial_vol17_bou0_lay2_app2_sen0_rho',
'SurfaceMaterial_vol17_bou0_lay2_app2_sen0_t',
'SurfaceMaterial_vol17_bou0_lay2_app2_sen0_x0',

'SurfaceMaterial_vol17_bou0_lay4_app2_sen0_rho',
'SurfaceMaterial_vol17_bou0_lay4_app2_sen0_t',
'SurfaceMaterial_vol17_bou0_lay4_app2_sen0_x0',

'SurfaceMaterial_vol17_bou0_lay6_app2_sen0_rho',
'SurfaceMaterial_vol17_bou0_lay6_app2_sen0_t',
'SurfaceMaterial_vol17_bou0_lay6_app2_sen0_x0',

'SurfaceMaterial_vol17_bou0_lay8_app2_sen0_rho',
'SurfaceMaterial_vol17_bou0_lay8_app2_sen0_t',
'SurfaceMaterial_vol17_bou0_lay8_app2_sen0_x0',

# %%
t = f['SurfaceMaterial_vol2_bou0_lay2_app0_sen0;1']
for key in t.keys():
    print(key)
# Out:
# n;1
# v;1
# o;1
# min;1
# max;1
# t;1
# x0;1
# l0;1
# A;1
# Z;1
# rho;1

# %%
file = uproot.open("/data/jlai/iris-hep/acts/thirdparty/OpenDataDetector/data/odd-material-maps.root")

def hist_mean_std(key):
    hist = file[key]
    values = hist.values()
    valid = values[~np.isnan(values)]

    # loc = np.where(valid!=0)
    # valid = valid[loc]

    mean = np.mean(valid)
    std = np.std(valid)
    print(f"Average: {mean:.4f}, Std Dev: {std:.4f}, Non-zero bins: {np.count_nonzero(valid)}")
    # return 


hist_mean_std('SurfaceMaterial_vol2_bou0_lay2_app0_sen0/t;1')
hist_mean_std('SurfaceMaterial_vol2_bou0_lay2_app0_sen0/x0;1')

hist_mean_std('SurfaceMaterial_vol17_bou0_lay2_app2_sen0/t;1')
hist_mean_std('SurfaceMaterial_vol17_bou0_lay2_app2_sen0/x0;1')

hist_mean_std('SurfaceMaterial_vol17_bou0_lay4_app2_sen0/t;1')
hist_mean_std('SurfaceMaterial_vol17_bou0_lay4_app2_sen0/x0;1')
# Out:
# Average: 0.1638, Std Dev: 0.3276, Non-zero bins: 288
# Average: 70.9666, Std Dev: 141.9445, Non-zero bins: 288
# Average: 4.3350, Std Dev: 0.8761, Non-zero bins: 28800
# Average: 313.3173, Std Dev: 117.4884, Non-zero bins: 28800
# Average: 4.1948, Std Dev: 0.9296, Non-zero bins: 28797
# Average: 300.2811, Std Dev: 104.5553, Non-zero bins: 28797

# %%
4.1948 / 300.2811
# Out:
# 0.0139695771728557

# %%
4.3350 / 313.3173
# Out:
# 0.013835814364543548

# %%
0.8188/ 354.8329
# Out:
# 0.0023075650538605637

# %%
hist = f["SurfaceMaterial_vol2_bou0_lay2_app0_sen0/x0"]

# Convert to numpy arrays
values, edges_x, edges_y = hist.to_numpy()

# Plot with matplotlib
plt.figure(figsize=(8, 6))
plt.pcolormesh(edges_x, edges_y, values.T, cmap="viridis")
plt.colorbar(label="x/X₀")
plt.xlabel("X (bins or mm)")
plt.ylabel("Y (bins or mm)")
plt.title("Material Map: x/X₀")
plt.tight_layout()
plt.show()
